# %%
import pyclifford as pc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import pyclifford as pc
#
# ModuleNotFoundError: No module named 'pyclifford'
